# %% [markdown]
# ## An Introduction to Linear Learner
#
# Welcome to our example introducing Amazon SageMaker's Linear Learner Algorithm!  Today, we use the Boston Housing dataset, present in Scikit-Learn: https://scikit-learn.org/stable/datasets/index.html#boston-dataset.
#
# The method that we'll use is a linear regression model.  Linear models are supervised learning algorithms used for solving either classification or regression problems.  As input, the model is given labeled examples ( **`x`**, `y`). **`x`** is a high dimensional vector and `y` is a numeric label.  Since we are doing regression, the algorithm expects the label to be be continuous values.  The algorithm learns a linear function, mapping the vector **`x`** to an approximation of the label `y`.
#
# Amazon SageMaker's Linear Learner algorithm extends upon typical linear models by training many models in parallel, in a computationally efficient manner.  Each model has a different set of hyperparameters, and then the algorithm finds the set that optimizes a specific criteria. This can provide substantially more accurate models than typical linear algorithms at the same, or lower, cost.
#
# To get started, we need to set up the environment with a few prerequisite steps, for permissions, configurations, and so on.

# %%
import datetime
import tarfile
import re
from sagemaker import get_execution_role
import boto3
import pandas as pd
import numpy as np
from sagemaker import get_execution_role
import sagemaker
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
import os


sm_boto3 = boto3.client('sagemaker')
sess = sagemaker.Session()
region = sess.boto_session.region_name
role = get_execution_role()

# %% [markdown]
# ## Preparation
#
# _This notebook was created and tested on an ml.m4.xlarge notebook instance._
#
# Let's start by specifying:
#
# - The S3 bucket and prefix that you want to use for training and model data.  This should be within the same region as the Notebook Instance, training, and hosting.
# - The IAM role arn used to give training and hosting access to your data. See the documentation for how to create these.  Note, if more than one role is required for notebook instances, training, and/or hosting, please replace the boto regexp with a the appropriate full IAM role arn string(s).

# %%
bucket = 'demo-saeed'
prefix = 'sagemaker/LL'
print('Using bucket ' + bucket)
role = get_execution_role()
# Out:
# Using bucket demo-saeed

# %% [markdown]
# ## Prepare data
# We load a dataset from sklearn, split it and send it to S3.
#
# More info on the dataset:
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic prices and the demand for clean air', J. Environ. Economics & Management, vol.5, 81-102, 1978. Used in Belsley, Kuh & Welsch, 'Regression diagnostics ...', Wiley, 1980. N.B. Various transformations are used in the table on pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression problems.
# References
#
#  * Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#  * Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
# we use the Boston housing dataset 
data = load_boston()
model_data = pd.DataFrame(data.data, columns=data.feature_names)
model_data.insert(loc=0, column='target', value=data.target)
model_data.head()
# Out:
#    target     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# when building a model whose primary goal is to predict a target value on new data, it is important to prevent overfitting. The most common way of preventing this is to build models with the concept that a model shouldn't only be judged on its fit to the data it was trained on, but also on "new" data.  There are several different ways of operationalizing this, holdout validation, cross-validation, leave-one-out validation, etc.  For our purposes, we'll simply randomly split the data into 3 uneven groups.  The model will be trained on 70% of data, it will then be evaluated on 20% of data to give us an estimate of the accuracy we hope to have on "new" data, and 10% will be held back as a final testing dataset which will be used later on.

# %%
train_data, validation_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), [int(0.7 * len(model_data)), int(0.9 * len(model_data))])   # Randomly sort the data then split out first 70%, second 20%, and last 10%

# %% [markdown]
# Amazon SageMaker's Linear Learner container expects data in the libSVM or CSV data format.  For this example, we'll stick to CSV.  Note that the first column must be the target variable and the CSV should not include headers.  Also, notice that although repetitive it's easiest to do this after the train|validation|test split rather than before. This avoids any misalignment issues due to random reordering.

# %%
train_data.to_csv('boston_train.csv', index = None, header = None)
validation_data.to_csv('boston_validation.csv', index = None, header = None)
test_data.to_csv('boston_test.csv', index = None, header = None)

# %% [markdown]
# Now we'll copy the file to S3 for Amazon SageMaker's managed training to pickup.

# %%
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('boston_train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('boston_validation.csv')

# %% [markdown]
# ## Training
# Once we have the data preprocessed and available in the correct format for training, the next step is to actually train the model using the data. Since this data is relatively small, it isn't meant to show off the performance of the Linear Learner training algorithm, although we have tested it on multi-terabyte datasets.
#
# Again, we'll use the Amazon SageMaker Python SDK to kick off training, and monitor status until it is completed.  In this example that takes between 7 and 11 minutes.  Despite the dataset being small, provisioning hardware and loading the algorithm container take time upfront.
#
# First, let's specify our containers.  Since we want this notebook to run in all 4 of Amazon SageMaker's regions, we'll create a small lookup.  More details on algorithm containers can be found in [AWS documentation](https://docs-aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html).

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'linear-learner')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %% [markdown]
# Then, because we're training with the CSV file format, we'll create `s3_input`s that our training function can use as a pointer to the files in S3, which also specify that the content type is CSV.

# %%
s3_input_train = sagemaker.s3_input(s3_data='s3://{}/{}/train/'.format(bucket, prefix), content_type='text/csv')
s3_input_validation = sagemaker.s3_input(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='text/csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %% [markdown]
# Next we'll kick off the base estimator, making sure to pass in the necessary hyperparameters.  Notice:
# - `feature_dim` is set to 13, which is the number of columns in the dataset.
# - `predictor_type` is set to 'regressor' since we are trying to predict the price of a house which is a continous value.
# - `mini_batch_size` is set to 100.  This value can be tuned for relatively minor improvements in fit and speed, but selecting a reasonable value relative to the dataset is appropriate in most cases.

# %%
sess = sagemaker.Session()

ll = sagemaker.estimator.Estimator(container,
                                    role, 
                                    train_instance_count=1, 
                                    train_instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket, prefix),
                                    sagemaker_session=sess)
ll.set_hyperparameters(feature_dim=13,
                           predictor_type='regressor',
                           mini_batch_size=100)

ll.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.
# 2020-08-05 17:04:20 Starting - Starting the training job...
# 2020-08-05 17:04:23 Starting - Launching requested ML instances......
# 2020-08-05 17:05:39 Starting - Preparing the instances for training......
# 2020-08-05 17:06:41 Downloading - Downloading input data......
# 2020-08-05 17:07:48 Training - Training image download completed. Training in progress..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [08/05/2020 17:07:51 INFO 140334513264448] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [08/05/2020 17:07:51 INFO 140334513264448] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'13', u'mini_batch_size': u'100', u'predictor_type': u'regressor'}
# [08/05/2020 17:07:51 INFO 140334513264448] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'13', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'100', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [08/05/2020 17:07:51 WARNING 140334513264448] Loggers have already been setup.
# Process 1 is a worker.
# [08/05/2020 17:07:51 INFO 140334513264448] Using default worker.
# [08/05/2020 17:07:51 INFO 140334513264448] Checkpoint loading and saving are disabled.
# [08/05/2020 17:07:51 INFO 140334513264448] Create Store: local
# [08/05/2020 17:07:51 INFO 140334513264448] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7fa1cdfa9c10>
# [08/05/2020 17:07:51 INFO 140334513264448] Scaling model computed with parameters:
#  {'stdev_weight':
# [1.03075275e+01 2.32479019e+01 6.92205620e+00 2.60682851e-01
#  1.20917335e-01 7.01248288e-01 2.76526642e+01 2.19241333e+00
#  9.09120464e+00 1.72137146e+02 2.14021349e+00 9.73916779e+01
#  7.50729561e+00]
# <NDArray 13 @cpu(0)>, 'stdev_label':
# [9.247231]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [22.015]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [4.4885049e+00 1.1173333e+01 1.1490433e+01 7.3333330e-02 5.6247938e-01
#  6.2533364e+00 7.0159004e+01 3.7881823e+00 1.0163333e+01 4.1932333e+02
#  1.8539001e+01 3.5291113e+02 1.3394634e+01]
# <NDArray 13 @cpu(0)>}
# [08/05/2020 17:07:51 INFO 140334513264448] nvidia-smi took: 0.0755548477173 secs to identify 0 gpus
# [08/05/2020 17:07:51 INFO 140334513264448] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Total Records Seen": {"count": 1, "max": 454, "sum": 454.0, "min": 454}, "Max Records Seen Between Resets": {"count": 1, "max": 354, "sum": 354.0, "min": 354}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1596647271.911571, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1596647271.911527}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9157295227050781, "sum": 0.9157295227050781, "min": 0.9157295227050781}}, "EndTime": 1596647271.994205, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.994138}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.844007314046224, "sum": 0.844007314046224, "min": 0.844007314046224}}, "EndTime": 1596647271.994301, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.99428}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2815505981445312, "sum": 1.2815505981445312, "min": 1.2815505981445312}}, "EndTime": 1596647271.994374, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.994353}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8335417048136393, "sum": 0.8335417048136393, "min": 0.8335417048136393}}, "EndTime": 1596647271.994445, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.994427}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0719722366333009, "sum": 1.0719722366333009, "min": 1.0719722366333009}}, "EndTime": 1596647271.994512, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.994493}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1436031341552735, "sum": 1.1436031341552735, "min": 1.1436031341552735}}, "EndTime": 1596647271.994575, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.994558}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2671587626139322, "sum": 1.2671587626139322, "min": 1.2671587626139322}}, "EndTime": 1596647271.994638, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.99462}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1955855814615886, "sum": 1.1955855814615886, "min": 1.1955855814615886}}, "EndTime": 1596647271.99471, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.994693}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8978092702229817, "sum": 0.8978092702229817, "min": 0.8978092702229817}}, "EndTime": 1596647271.994776, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.994757}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.360770492553711, "sum": 1.360770492553711, "min": 1.360770492553711}}, "EndTime": 1596647271.994841, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.994822}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8303632354736328, "sum": 0.8303632354736328, "min": 0.8303632354736328}}, "EndTime": 1596647271.994905, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.994887}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0781469217936197, "sum": 1.0781469217936197, "min": 1.0781469217936197}}, "EndTime": 1596647271.994975, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.99496}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1538421885172525, "sum": 1.1538421885172525, "min": 1.1538421885172525}}, "EndTime": 1596647271.995034, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995016}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2229008229573568, "sum": 1.2229008229573568, "min": 1.2229008229573568}}, "EndTime": 1596647271.995098, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995081}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1024784851074219, "sum": 1.1024784851074219, "min": 1.1024784851074219}}, "EndTime": 1596647271.99516, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995143}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1229730478922526, "sum": 1.1229730478922526, "min": 1.1229730478922526}}, "EndTime": 1596647271.995229, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995211}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0047226206461588, "sum": 1.0047226206461588, "min": 1.0047226206461588}}, "EndTime": 1596647271.99528, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995263}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.831771608988444, "sum": 0.831771608988444, "min": 0.831771608988444}}, "EndTime": 1596647271.995342, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995325}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1840611012776692, "sum": 1.1840611012776692, "min": 1.1840611012776692}}, "EndTime": 1596647271.995404, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995387}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.003741226196289, "sum": 1.003741226196289, "min": 1.003741226196289}}, "EndTime": 1596647271.99547, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995451}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0580668385823568, "sum": 1.0580668385823568, "min": 1.0580668385823568}}, "EndTime": 1596647271.995536, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995518}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2185489908854166, "sum": 1.2185489908854166, "min": 1.2185489908854166}}, "EndTime": 1596647271.995596, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995583}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9647942733764648, "sum": 0.9647942733764648, "min": 0.9647942733764648}}, "EndTime": 1596647271.995661, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995644}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.007819366455078, "sum": 1.007819366455078, "min": 1.007819366455078}}, "EndTime": 1596647271.995729, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995711}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9682867177327474, "sum": 0.9682867177327474, "min": 0.9682867177327474}}, "EndTime": 1596647271.995794, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995777}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9566775767008463, "sum": 0.9566775767008463, "min": 0.9566775767008463}}, "EndTime": 1596647271.995867, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995848}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1932875315348308, "sum": 1.1932875315348308, "min": 1.1932875315348308}}, "EndTime": 1596647271.995931, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995914}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.119784418741862, "sum": 1.119784418741862, "min": 1.119784418741862}}, "EndTime": 1596647271.995993, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.995977}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3265743255615234, "sum": 1.3265743255615234, "min": 1.3265743255615234}}, "EndTime": 1596647271.996068, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.996049}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.4062883758544922, "sum": 1.4062883758544922, "min": 1.4062883758544922}}, "EndTime": 1596647271.996117, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.9961}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2846174875895182, "sum": 1.2846174875895182, "min": 1.2846174875895182}}, "EndTime": 1596647271.996181, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.996163}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2594183858235677, "sum": 1.2594183858235677, "min": 1.2594183858235677}}, "EndTime": 1596647271.996247, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.99623}
#
# [08/05/2020 17:07:51 INFO 140334513264448] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.915729522705
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 56.66774169053181, "sum": 56.66774169053181, "min": 56.66774169053181}}, "EndTime": 1596647272.056929, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.056862}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 50.33139362901744, "sum": 50.33139362901744, "min": 50.33139362901744}}, "EndTime": 1596647272.057019, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057004}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 75.70260676771107, "sum": 75.70260676771107, "min": 75.70260676771107}}, "EndTime": 1596647272.057094, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057074}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 50.944248803771366, "sum": 50.944248803771366, "min": 50.944248803771366}}, "EndTime": 1596647272.057155, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057143}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 52.96712395696357, "sum": 52.96712395696357, "min": 52.96712395696357}}, "EndTime": 1596647272.057227, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057208}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 66.48223975153253, "sum": 66.48223975153253, "min": 66.48223975153253}}, "EndTime": 1596647272.057288, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057276}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 59.16385531661534, "sum": 59.16385531661534, "min": 59.16385531661534}}, "EndTime": 1596647272.057351, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057332}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 66.57163457587214, "sum": 66.57163457587214, "min": 66.57163457587214}}, "EndTime": 1596647272.057423, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057404}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 53.14417527453734, "sum": 53.14417527453734, "min": 53.14417527453734}}, "EndTime": 1596647272.057489, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057472}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 83.20278530309696, "sum": 83.20278530309696, "min": 83.20278530309696}}, "EndTime": 1596647272.057556, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057538}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 49.40072765916881, "sum": 49.40072765916881, "min": 49.40072765916881}}, "EndTime": 1596647272.057621, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057602}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.58967356162496, "sum": 63.58967356162496, "min": 63.58967356162496}}, "EndTime": 1596647272.057676, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057664}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 60.066283575379025, "sum": 60.066283575379025, "min": 60.066283575379025}}, "EndTime": 1596647272.05771, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057701}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 53.26897271788946, "sum": 53.26897271788946, "min": 53.26897271788946}}, "EndTime": 1596647272.057763, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057746}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 44.19134181560856, "sum": 44.19134181560856, "min": 44.19134181560856}}, "EndTime": 1596647272.057827, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.05781}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 68.59176091864558, "sum": 68.59176091864558, "min": 68.59176091864558}}, "EndTime": 1596647272.057892, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057874}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.49120644295569, "sum": 63.49120644295569, "min": 63.49120644295569}}, "EndTime": 1596647272.057966, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.057947}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 47.93224353601437, "sum": 47.93224353601437, "min": 47.93224353601437}}, "EndTime": 1596647272.05803, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.058013}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 76.44460798962281, "sum": 76.44460798962281, "min": 76.44460798962281}}, "EndTime": 1596647272.058094, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.058077}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 67.08340136839611, "sum": 67.08340136839611, "min": 67.08340136839611}}, "EndTime": 1596647272.058161, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.058143}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 40.2591605233674, "sum": 40.2591605233674, "min": 40.2591605233674}}, "EndTime": 1596647272.058228, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.058209}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 54.27677553006918, "sum": 54.27677553006918, "min": 54.27677553006918}}, "EndTime": 1596647272.058292, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.058274}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 40.677268415394394, "sum": 40.677268415394394, "min": 40.677268415394394}}, "EndTime": 1596647272.058357, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.058338}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 43.13304780261351, "sum": 43.13304780261351, "min": 43.13304780261351}}, "EndTime": 1596647272.058421, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.058405}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 67.78686379914237, "sum": 67.78686379914237, "min": 67.78686379914237}}, "EndTime": 1596647272.058489, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.05847}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 68.5596467386378, "sum": 68.5596467386378, "min": 68.5596467386378}}, "EndTime": 1596647272.058536, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.058526}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 77.78160716519497, "sum": 77.78160716519497, "min": 77.78160716519497}}, "EndTime": 1596647272.058569, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.05856}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 74.88657433915846, "sum": 74.88657433915846, "min": 74.88657433915846}}, "EndTime": 1596647272.058601, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.058592}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 67.9911391003297, "sum": 67.9911391003297, "min": 67.9911391003297}}, "EndTime": 1596647272.058657, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.05864}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 65.54426701840862, "sum": 65.54426701840862, "min": 65.54426701840862}}, "EndTime": 1596647272.058723, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.058704}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 71.50760039598634, "sum": 71.50760039598634, "min": 71.50760039598634}}, "EndTime": 1596647272.0588, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.058781}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 72.71514997033789, "sum": 72.71514997033789, "min": 72.71514997033789}}, "EndTime": 1596647272.058866, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647272.058848}
#
# [08/05/2020 17:07:52 INFO 140334513264448] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=56.6677416905
# [08/05/2020 17:07:52 INFO 140334513264448] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=40.2591605234
# [08/05/2020 17:07:52 INFO 140334513264448] Epoch 0: Loss improved. Updating best model
# [08/05/2020 17:07:52 INFO 140334513264448] Saving model for epoch: 0
# [08/05/2020 17:07:52 INFO 140334513264448] Saved checkpoint to "/tmp/tmpglRZ56/mx-mod-0000.params"
# [08/05/2020 17:07:52 INFO 140334513264448] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Records Since Last Reset": {"count": 1, "max": 354, "sum": 354.0, "min": 354}, "Total Batches Seen": {"count": 1, "max": 9, "sum": 9.0, "min": 9}, "Total Records Seen": {"count": 1, "max": 808, "sum": 808.0, "min": 808}, "Max Records Seen Between Resets": {"count": 1, "max": 354, "sum": 354.0, "min": 354}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1596647272.06971, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1596647271.911844}
#
# [08/05/2020 17:07:52 INFO 140334513264448] #throughput_metric: host=algo-1, train throughput=2239.62437609 records/second
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7749149449666342, "sum": 0.7749149449666342, "min": 0.7749149449666342}}, "EndTime": 1596647272.142781, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.142718}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.725079345703125, "sum": 0.725079345703125, "min": 0.725079345703125}}, "EndTime": 1596647272.142863, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.14285}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0809105936686199, "sum": 1.0809105936686199, "min": 1.0809105936686199}}, "EndTime": 1596647272.142924, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.142907}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7130473963419597, "sum": 0.7130473963419597, "min": 0.7130473963419597}}, "EndTime": 1596647272.142989, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.142972}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8171707280476888, "sum": 0.8171707280476888, "min": 0.8171707280476888}}, "EndTime": 1596647272.14306, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143043}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8731553904215494, "sum": 0.8731553904215494, "min": 0.8731553904215494}}, "EndTime": 1596647272.143128, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143112}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8582601420084636, "sum": 0.8582601420084636, "min": 0.8582601420084636}}, "EndTime": 1596647272.143183, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143168}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8635453033447266, "sum": 0.8635453033447266, "min": 0.8635453033447266}}, "EndTime": 1596647272.143238, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143223}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.779425163269043, "sum": 0.779425163269043, "min": 0.779425163269043}}, "EndTime": 1596647272.143298, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143281}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.149157231648763, "sum": 1.149157231648763, "min": 1.149157231648763}}, "EndTime": 1596647272.143358, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143341}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7216998291015625, "sum": 0.7216998291015625, "min": 0.7216998291015625}}, "EndTime": 1596647272.143417, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143401}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9221296183268229, "sum": 0.9221296183268229, "min": 0.9221296183268229}}, "EndTime": 1596647272.14348, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143462}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8433834075927734, "sum": 0.8433834075927734, "min": 0.8433834075927734}}, "EndTime": 1596647272.143587, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143524}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8080346171061198, "sum": 0.8080346171061198, "min": 0.8080346171061198}}, "EndTime": 1596647272.143657, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143638}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7946420415242513, "sum": 0.7946420415242513, "min": 0.7946420415242513}}, "EndTime": 1596647272.143697, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143688}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8801154581705729, "sum": 0.8801154581705729, "min": 0.8801154581705729}}, "EndTime": 1596647272.143753, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143738}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8542747624715169, "sum": 0.8542747624715169, "min": 0.8542747624715169}}, "EndTime": 1596647272.143815, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143803}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7281578954060872, "sum": 0.7281578954060872, "min": 0.7281578954060872}}, "EndTime": 1596647272.143881, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143865}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0187203979492188, "sum": 1.0187203979492188, "min": 1.0187203979492188}}, "EndTime": 1596647272.143942, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143925}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8598412322998047, "sum": 0.8598412322998047, "min": 0.8598412322998047}}, "EndTime": 1596647272.144002, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.143986}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8981742350260417, "sum": 0.8981742350260417, "min": 0.8981742350260417}}, "EndTime": 1596647272.144106, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.144058}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8399614461263021, "sum": 0.8399614461263021, "min": 0.8399614461263021}}, "EndTime": 1596647272.144182, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.144164}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8838169606526692, "sum": 0.8838169606526692, "min": 0.8838169606526692}}, "EndTime": 1596647272.144256, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.144238}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8522576141357422, "sum": 0.8522576141357422, "min": 0.8522576141357422}}, "EndTime": 1596647272.144328, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.14431}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9542444101969401, "sum": 0.9542444101969401, "min": 0.9542444101969401}}, "EndTime": 1596647272.1444, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.144383}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9683028157552084, "sum": 0.9683028157552084, "min": 0.9683028157552084}}, "EndTime": 1596647272.144462, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.144446}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0689105478922527, "sum": 1.0689105478922527, "min": 1.0689105478922527}}, "EndTime": 1596647272.144531, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.144514}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.068066864013672, "sum": 1.068066864013672, "min": 1.068066864013672}}, "EndTime": 1596647272.144628, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.144608}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.321297378540039, "sum": 1.321297378540039, "min": 1.321297378540039}}, "EndTime": 1596647272.14469, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.144674}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2242768096923828, "sum": 1.2242768096923828, "min": 1.2242768096923828}}, "EndTime": 1596647272.14475, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.144733}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3915838368733724, "sum": 1.3915838368733724, "min": 1.3915838368733724}}, "EndTime": 1596647272.144809, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.144792}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3967746988932292, "sum": 1.3967746988932292, "min": 1.3967746988932292}}, "EndTime": 1596647272.14487, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.144854}
#
# [08/05/2020 17:07:52 INFO 140334513264448] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.774914944967
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 47.16155993584359, "sum": 47.16155993584359, "min": 47.16155993584359}}, "EndTime": 1596647272.20348, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.20338}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 42.63465331804635, "sum": 42.63465331804635, "min": 42.63465331804635}}, "EndTime": 1596647272.2036, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.203576}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 62.49322658954281, "sum": 62.49322658954281, "min": 62.49322658954281}}, "EndTime": 1596647272.203674, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.203655}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 43.22598624465489, "sum": 43.22598624465489, "min": 43.22598624465489}}, "EndTime": 1596647272.203741, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.203719}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 48.66569005380763, "sum": 48.66569005380763, "min": 48.66569005380763}}, "EndTime": 1596647272.203802, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.203786}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 43.346682557965266, "sum": 43.346682557965266, "min": 43.346682557965266}}, "EndTime": 1596647272.203863, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.203846}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 46.07920172663018, "sum": 46.07920172663018, "min": 46.07920172663018}}, "EndTime": 1596647272.203925, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.203908}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 47.27044692842087, "sum": 47.27044692842087, "min": 47.27044692842087}}, "EndTime": 1596647272.203984, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.203969}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 45.79308701505755, "sum": 45.79308701505755, "min": 45.79308701505755}}, "EndTime": 1596647272.204052, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204035}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 69.13524665454827, "sum": 69.13524665454827, "min": 69.13524665454827}}, "EndTime": 1596647272.204112, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204097}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 42.42006269775995, "sum": 42.42006269775995, "min": 42.42006269775995}}, "EndTime": 1596647272.204176, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.20416}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 53.13559314992168, "sum": 53.13559314992168, "min": 53.13559314992168}}, "EndTime": 1596647272.204233, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204218}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 46.22301445385017, "sum": 46.22301445385017, "min": 46.22301445385017}}, "EndTime": 1596647272.204288, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204273}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 47.934021600402225, "sum": 47.934021600402225, "min": 47.934021600402225}}, "EndTime": 1596647272.204341, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204327}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 51.66703207185953, "sum": 51.66703207185953, "min": 51.66703207185953}}, "EndTime": 1596647272.204396, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204381}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 45.164877712136445, "sum": 45.164877712136445, "min": 45.164877712136445}}, "EndTime": 1596647272.20445, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204436}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 53.515167538482366, "sum": 53.515167538482366, "min": 53.515167538482366}}, "EndTime": 1596647272.204506, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204491}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 41.37326487928334, "sum": 41.37326487928334, "min": 41.37326487928334}}, "EndTime": 1596647272.20459, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.20457}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 65.16580041564337, "sum": 65.16580041564337, "min": 65.16580041564337}}, "EndTime": 1596647272.204651, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204635}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 56.86548444540194, "sum": 56.86548444540194, "min": 56.86548444540194}}, "EndTime": 1596647272.204709, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204693}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 42.66697723086518, "sum": 42.66697723086518, "min": 42.66697723086518}}, "EndTime": 1596647272.204768, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204752}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 47.361566675771584, "sum": 47.361566675771584, "min": 47.361566675771584}}, "EndTime": 1596647272.204836, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204819}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 41.167666709068975, "sum": 41.167666709068975, "min": 41.167666709068975}}, "EndTime": 1596647272.204905, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204888}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 43.41534008366047, "sum": 43.41534008366047, "min": 43.41534008366047}}, "EndTime": 1596647272.204973, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.204956}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 65.77415488970162, "sum": 65.77415488970162, "min": 65.77415488970162}}, "EndTime": 1596647272.205041, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.205024}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 67.0133295909013, "sum": 67.0133295909013, "min": 67.0133295909013}}, "EndTime": 1596647272.205109, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.205092}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 69.14014268629622, "sum": 69.14014268629622, "min": 69.14014268629622}}, "EndTime": 1596647272.205167, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.205151}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 69.57388819326269, "sum": 69.57388819326269, "min": 69.57388819326269}}, "EndTime": 1596647272.205235, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.205218}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 69.90837347625506, "sum": 69.90837347625506, "min": 69.90837347625506}}, "EndTime": 1596647272.205295, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.205279}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 72.09554731757333, "sum": 72.09554731757333, "min": 72.09554731757333}}, "EndTime": 1596647272.205351, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.205336}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 78.36237317766293, "sum": 78.36237317766293, "min": 78.36237317766293}}, "EndTime": 1596647272.205411, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1596647272.205395}
#
# ...
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0061088307698567, "sum": 1.0061088307698567, "min": 1.0061088307698567}}, "EndTime": 1596647273.606469, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.606449}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9514552815755208, "sum": 0.9514552815755208, "min": 0.9514552815755208}}, "EndTime": 1596647273.606541, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.606523}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9825566101074219, "sum": 0.9825566101074219, "min": 0.9825566101074219}}, "EndTime": 1596647273.606613, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.606595}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9648655446370443, "sum": 0.9648655446370443, "min": 0.9648655446370443}}, "EndTime": 1596647273.606679, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.606661}
#
# [08/05/2020 17:07:53 INFO 140334513264448] #quality_metric: host=algo-1, epoch=11, train mse_objective <loss>=0.410455875397
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 25.67683141538412, "sum": 25.67683141538412, "min": 25.67683141538412}}, "EndTime": 1596647273.667268, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.667196}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 24.311182350215347, "sum": 24.311182350215347, "min": 24.311182350215347}}, "EndTime": 1596647273.667357, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.667342}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 28.167066361496943, "sum": 28.167066361496943, "min": 28.167066361496943}}, "EndTime": 1596647273.667422, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.667402}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 25.270145605106165, "sum": 25.270145605106165, "min": 25.270145605106165}}, "EndTime": 1596647273.667488, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.66747}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.110357983277577, "sum": 19.110357983277577, "min": 19.110357983277577}}, "EndTime": 1596647273.667549, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.667531}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.735668484527285, "sum": 19.735668484527285, "min": 19.735668484527285}}, "EndTime": 1596647273.66762, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.667601}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.70797291368541, "sum": 19.70797291368541, "min": 19.70797291368541}}, "EndTime": 1596647273.667683, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.667666}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.563765346413792, "sum": 19.563765346413792, "min": 19.563765346413792}}, "EndTime": 1596647273.667749, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.667729}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 26.60931123601328, "sum": 26.60931123601328, "min": 26.60931123601328}}, "EndTime": 1596647273.667811, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.667794}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 29.57529167395712, "sum": 29.57529167395712, "min": 29.57529167395712}}, "EndTime": 1596647273.667877, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.667859}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 25.385996336984164, "sum": 25.385996336984164, "min": 25.385996336984164}}, "EndTime": 1596647273.667949, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.667931}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 25.903978359359915, "sum": 25.903978359359915, "min": 25.903978359359915}}, "EndTime": 1596647273.668021, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668004}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 18.77112330068456, "sum": 18.77112330068456, "min": 18.77112330068456}}, "EndTime": 1596647273.668085, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668068}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.354807636525372, "sum": 19.354807636525372, "min": 19.354807636525372}}, "EndTime": 1596647273.668142, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668129}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 18.966983870704574, "sum": 18.966983870704574, "min": 18.966983870704574}}, "EndTime": 1596647273.668205, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668188}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.715665836145384, "sum": 19.715665836145384, "min": 19.715665836145384}}, "EndTime": 1596647273.668272, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668256}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 28.35181225327277, "sum": 28.35181225327277, "min": 28.35181225327277}}, "EndTime": 1596647273.668336, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668318}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 26.029394907526452, "sum": 26.029394907526452, "min": 26.029394907526452}}, "EndTime": 1596647273.6684, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668383}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 32.35178452435106, "sum": 32.35178452435106, "min": 32.35178452435106}}, "EndTime": 1596647273.668468, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668451}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 28.719866126111828, "sum": 28.719866126111828, "min": 28.719866126111828}}, "EndTime": 1596647273.668531, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668513}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 24.34439781632754, "sum": 24.34439781632754, "min": 24.34439781632754}}, "EndTime": 1596647273.668619, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.6686}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 22.63067575020365, "sum": 22.63067575020365, "min": 22.63067575020365}}, "EndTime": 1596647273.668685, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668668}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 23.53844390057101, "sum": 23.53844390057101, "min": 23.53844390057101}}, "EndTime": 1596647273.668749, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668732}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 23.87586510063398, "sum": 23.87586510063398, "min": 23.87586510063398}}, "EndTime": 1596647273.668823, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668804}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 64.08933363810624, "sum": 64.08933363810624, "min": 64.08933363810624}}, "EndTime": 1596647273.66889, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668872}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 64.12237890640108, "sum": 64.12237890640108, "min": 64.12237890640108}}, "EndTime": 1596647273.668951, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668936}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 64.60378575088954, "sum": 64.60378575088954, "min": 64.60378575088954}}, "EndTime": 1596647273.668986, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.668978}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.874805393785536, "sum": 63.874805393785536, "min": 63.874805393785536}}, "EndTime": 1596647273.669017, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.669009}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 65.92847931739128, "sum": 65.92847931739128, "min": 65.92847931739128}}, "EndTime": 1596647273.669076, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.669059}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 67.92899498136917, "sum": 67.92899498136917, "min": 67.92899498136917}}, "EndTime": 1596647273.669148, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.66913}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 64.35275128808352, "sum": 64.35275128808352, "min": 64.35275128808352}}, "EndTime": 1596647273.66922, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.669203}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.90203256890325, "sum": 63.90203256890325, "min": 63.90203256890325}}, "EndTime": 1596647273.669284, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.669266}
#
# [08/05/2020 17:07:53 INFO 140334513264448] #quality_metric: host=algo-1, epoch=11, validation mse_objective <loss>=25.6768314154
# [08/05/2020 17:07:53 INFO 140334513264448] #early_stopping_criteria_metric: host=algo-1, epoch=11, criteria=mse_objective, value=18.7711233007
# [08/05/2020 17:07:53 INFO 140334513264448] Saving model for epoch: 11
# [08/05/2020 17:07:53 INFO 140334513264448] Saved checkpoint to "/tmp/tmp61j1tT/mx-mod-0000.params"
# [08/05/2020 17:07:53 INFO 140334513264448] Early stop condition met. Stopping training.
# [08/05/2020 17:07:53 INFO 140334513264448] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Records Since Last Reset": {"count": 1, "max": 354, "sum": 354.0, "min": 354}, "Total Batches Seen": {"count": 1, "max": 53, "sum": 53.0, "min": 53}, "Total Records Seen": {"count": 1, "max": 4702, "sum": 4702.0, "min": 4702}, "Max Records Seen Between Resets": {"count": 1, "max": 354, "sum": 354.0, "min": 354}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1596647273.676687, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1596647273.532518}
#
# [08/05/2020 17:07:53 INFO 140334513264448] #throughput_metric: host=algo-1, train throughput=2452.96739308 records/second
# [08/05/2020 17:07:53 WARNING 140334513264448] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [08/05/2020 17:07:53 WARNING 140334513264448] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [08/05/2020 17:07:53 INFO 140334513264448] #early_stopping_criteria_metric: host=algo-1, epoch=11, criteria=mse_objective, value=18.7711233007
# [08/05/2020 17:07:53 INFO 140334513264448] #validation_score (algo-1) : ('mse_objective', 18.770652091149056)
# [08/05/2020 17:07:53 INFO 140334513264448] #validation_score (algo-1) : ('mse', 18.770652091149056)
# [08/05/2020 17:07:53 INFO 140334513264448] #validation_score (algo-1) : ('absolute_loss', 2.929951280650526)
# [08/05/2020 17:07:53 INFO 140334513264448] #quality_metric: host=algo-1, validation mse_objective <loss>=18.7706520911
# [08/05/2020 17:07:53 INFO 140334513264448] #quality_metric: host=algo-1, validation mse <loss>=18.7706520911
# [08/05/2020 17:07:53 INFO 140334513264448] #quality_metric: host=algo-1, validation absolute_loss <loss>=2.92995128065
# [08/05/2020 17:07:53 INFO 140334513264448] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.01, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [08/05/2020 17:07:53 INFO 140334513264448] Saved checkpoint to "/tmp/tmpmh6dav/mx-mod-0000.params"
# [08/05/2020 17:07:53 INFO 140334513264448] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2371.946096420288, "sum": 2371.946096420288, "min": 2371.946096420288}, "finalize.time": {"count": 1, "max": 94.76709365844727, "sum": 94.76709365844727, "min": 94.76709365844727}, "initialize.time": {"count": 1, "max": 226.4881134033203, "sum": 226.4881134033203, "min": 226.4881134033203}, "check_early_stopping.time": {"count": 13, "max": 1.1279582977294922, "sum": 7.952690124511719, "min": 0.20384788513183594}, "setuptime": {"count": 1, "max": 28.142929077148438, "sum": 28.142929077148438, "min": 28.142929077148438}, "update.time": {"count": 12, "max": 194.86594200134277, "sum": 1723.9861488342285, "min": 110.08906364440918}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1596647273.778808, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1596647271.684713}
#
#
# 2020-08-05 17:08:06 Uploading - Uploading generated training model
# 2020-08-05 17:08:06 Completed - Training job completed
# Training seconds: 85
# Billable seconds: 85

# %% [markdown]
# ## Hosting
# Now that we've trained the `Linear Learner` algorithm on our data, let's deploy a model that's hosted behind a real-time endpoint.

# %%
ll_predictor = ll.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')

# %% [markdown]
# ### (Optional) Delete the Endpoint
#
# If you're ready to be done with this notebook, please run the delete_endpoint line in the cell below.  This will remove the hosted endpoint you created and avoid any charges from a stray instance being left on.

# %%
sagemaker.Session().delete_endpoint(ll_predictor.endpoint)
