# %% [markdown]
# ## An Introduction to Linear Learner
#
# Welcome to our example introducing Amazon SageMaker's Linear Learner Algorithm!  Today, we use the Boston Housing dataset, present in Scikit-Learn: https://scikit-learn.org/stable/datasets/index.html#boston-dataset.
#
# The method that we'll use is a linear regression model.  Linear models are supervised learning algorithms used for solving either classification or regression problems.  As input, the model is given labeled examples ( **`x`**, `y`). **`x`** is a high dimensional vector and `y` is a numeric label.  Since we are doing regression, the algorithm expects the label to be be continuous values.  The algorithm learns a linear function, mapping the vector **`x`** to an approximation of the label `y`.
#
# Amazon SageMaker's Linear Learner algorithm extends upon typical linear models by training many models in parallel, in a computationally efficient manner.  Each model has a different set of hyperparameters, and then the algorithm finds the set that optimizes a specific criteria. This can provide substantially more accurate models than typical linear algorithms at the same, or lower, cost.
#
# To get started, we need to set up the environment with a few prerequisite steps, for permissions, configurations, and so on.

# %%
import datetime
import tarfile
import re
from sagemaker import get_execution_role
import boto3
import pandas as pd
import numpy as np
from sagemaker import get_execution_role
import sagemaker
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_boston
import os


sm_boto3 = boto3.client('sagemaker')
sess = sagemaker.Session()
region = sess.boto_session.region_name
role = get_execution_role()

# %%
sagemaker.__version__
# Out:
# '2.16.4.dev0'

# %% [markdown]
# ## Preparation
#
# _This notebook was created and tested on an ml.m4.xlarge notebook instance._
#
# Let's start by specifying:
#
# - The S3 bucket and prefix that you want to use for training and model data.  This should be within the same region as the Notebook Instance, training, and hosting.
# - The IAM role arn used to give training and hosting access to your data. See the documentation for how to create these.  Note, if more than one role is required for notebook instances, training, and/or hosting, please replace the boto regexp with a the appropriate full IAM role arn string(s).

# %%
bucket = 'demo-saeed'
prefix = 'sagemaker/LL'
print('Using bucket ' + bucket)
role = get_execution_role()
# Out:
# Using bucket demo-saeed

# %% [markdown]
# ## Prepare data
# We load a dataset from sklearn, split it and send it to S3.
#
# More info on the dataset:
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic prices and the demand for clean air', J. Environ. Economics & Management, vol.5, 81-102, 1978. Used in Belsley, Kuh & Welsch, 'Regression diagnostics ...', Wiley, 1980. N.B. Various transformations are used in the table on pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression problems.
# References
#
#  * Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#  * Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %%
# we use the Boston housing dataset 
data = load_boston()
model_data = pd.DataFrame(data.data, columns=data.feature_names)
model_data.insert(loc=0, column='target', value=data.target)
model_data.head()
# Out:
#    target     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    24.0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    21.6  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    34.7  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    33.4  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    36.2  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %% [markdown]
# when building a model whose primary goal is to predict a target value on new data, it is important to prevent overfitting. The most common way of preventing this is to build models with the concept that a model shouldn't only be judged on its fit to the data it was trained on, but also on "new" data.  There are several different ways of operationalizing this, holdout validation, cross-validation, leave-one-out validation, etc.  For our purposes, we'll simply randomly split the data into 3 uneven groups.  The model will be trained on 70% of data, it will then be evaluated on 20% of data to give us an estimate of the accuracy we hope to have on "new" data, and 10% will be held back as a final testing dataset which will be used later on.

# %%
train_data, validation_data, test_data = np.split(model_data.sample(frac=1, random_state=1729), [int(0.7 * len(model_data)), int(0.9 * len(model_data))])   # Randomly sort the data then split out first 70%, second 20%, and last 10%

# %% [markdown]
# Amazon SageMaker's Linear Learner container expects data in the libSVM or CSV data format.  For this example, we'll stick to CSV.  Note that the first column must be the target variable and the CSV should not include headers.  Also, notice that although repetitive it's easiest to do this after the train|validation|test split rather than before. This avoids any misalignment issues due to random reordering.

# %%
train_data.to_csv('boston_train.csv', index = None, header = None)
validation_data.to_csv('boston_validation.csv', index = None, header = None)
test_data.to_csv('boston_test.csv', index = None, header = None)

# %% [markdown]
# Now we'll copy the file to S3 for Amazon SageMaker's managed training to pickup.

# %%
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train/train.csv')).upload_file('boston_train.csv')
boto3.Session().resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'validation/validation.csv')).upload_file('boston_validation.csv')

# %% [markdown]
# ## Training
# Once we have the data preprocessed and available in the correct format for training, the next step is to actually train the model using the data. Since this data is relatively small, it isn't meant to show off the performance of the Linear Learner training algorithm, although we have tested it on multi-terabyte datasets.
#
# Again, we'll use the Amazon SageMaker Python SDK to kick off training, and monitor status until it is completed.  In this example that takes between 7 and 11 minutes.  Despite the dataset being small, provisioning hardware and loading the algorithm container take time upfront.
#
# First, let's specify our containers.  Since we want this notebook to run in all 4 of Amazon SageMaker's regions, we'll create a small lookup.  More details on algorithm containers can be found in [AWS documentation](https://docs-aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html).

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
container = sagemaker.image_uris.retrieve( "linear-learner", region = boto3.Session().region_name)

# %% [markdown]
# Then, because we're training with the CSV file format, we'll create `s3_input`s that our training function can use as a pointer to the files in S3, which also specify that the content type is CSV.

# %%
s3_input_train = sagemaker.TrainingInput(s3_data='s3://{}/{}/train/'.format(bucket, prefix), content_type='text/csv')
s3_input_validation = sagemaker.TrainingInput(s3_data='s3://{}/{}/validation/'.format(bucket, prefix), content_type='text/csv')

# %% [markdown]
# Next we'll kick off the base estimator, making sure to pass in the necessary hyperparameters.  Notice:
# - `feature_dim` is set to 13, which is the number of columns in the dataset.
# - `predictor_type` is set to 'regressor' since we are trying to predict the price of a house which is a continous value.
# - `mini_batch_size` is set to 100.  This value can be tuned for relatively minor improvements in fit and speed, but selecting a reasonable value relative to the dataset is appropriate in most cases.

# %%
sess = sagemaker.Session()

ll = sagemaker.estimator.Estimator(container,
                                    role, 
                                    instance_count=1, 
                                    instance_type='ml.m4.xlarge',
                                    sagemaker_session=sess)
ll.set_hyperparameters(feature_dim=13,
                           predictor_type='regressor',
                           mini_batch_size=100)

ll.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-12-16 21:56:01 Starting - Starting the training job...
# 2020-12-16 21:56:25 Starting - Launching requested ML instancesProfilerReport-1608155761: InProgress
# ......
# 2020-12-16 21:57:31 Starting - Preparing the instances for training.........
# 2020-12-16 21:58:47 Downloading - Downloading input data...
# 2020-12-16 21:59:27 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
#
# 2020-12-16 21:59:54 Uploading - Uploading generated training model[12/16/2020 21:59:48 INFO 140694911018816] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'auto', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/16/2020 21:59:48 INFO 140694911018816] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {u'feature_dim': u'13', u'mini_batch_size': u'100', u'predictor_type': u'regressor'}
# [12/16/2020 21:59:48 INFO 140694911018816] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'13', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'100', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [12/16/2020 21:59:48 WARNING 140694911018816] Loggers have already been setup.
# Process 1 is a worker.
# [12/16/2020 21:59:48 INFO 140694911018816] Using default worker.
# [12/16/2020 21:59:49 INFO 140694911018816] Checkpoint loading and saving are disabled.
# [12/16/2020 21:59:49 INFO 140694911018816] Create Store: local
# [12/16/2020 21:59:49 INFO 140694911018816] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7ff5b7408f10>
# [12/16/2020 21:59:49 INFO 140694911018816] Scaling model computed with parameters:
#  {'stdev_weight':
# [1.0307528e+01 2.3247902e+01 6.9220562e+00 2.6068285e-01 1.2091733e-01
#  7.0124829e-01 2.7652664e+01 2.1924133e+00 9.0912037e+00 1.7213715e+02
#  2.1402135e+00 9.7391678e+01 7.5072956e+00]
# <NDArray 13 @cpu(0)>, 'stdev_label':
# [9.2472315]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [22.015]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [4.4885049e+00 1.1173334e+01 1.1490434e+01 7.3333338e-02 5.6247938e-01
#  6.2533369e+00 7.0159004e+01 3.7881825e+00 1.0163333e+01 4.1932336e+02
#  1.8539001e+01 3.5291110e+02 1.3394633e+01]
# <NDArray 13 @cpu(0)>}
# [12/16/2020 21:59:49 INFO 140694911018816] nvidia-smi took: 0.0251820087433 secs to identify 0 gpus
# [12/16/2020 21:59:49 INFO 140694911018816] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Total Records Seen": {"count": 1, "max": 454, "sum": 454.0, "min": 454}, "Max Records Seen Between Resets": {"count": 1, "max": 354, "sum": 354.0, "min": 354}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1608155989.307076, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1608155989.307034}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.915729268391927, "sum": 0.915729268391927, "min": 0.915729268391927}}, "EndTime": 1608155989.400182, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.400122}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8440070978800456, "sum": 0.8440070978800456, "min": 0.8440070978800456}}, "EndTime": 1608155989.400261, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.400246}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2815503438313802, "sum": 1.2815503438313802, "min": 1.2815503438313802}}, "EndTime": 1608155989.400338, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.400318}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8335414886474609, "sum": 0.8335414886474609, "min": 0.8335414886474609}}, "EndTime": 1608155989.400407, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.400388}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0719720967610677, "sum": 1.0719720967610677, "min": 1.0719720967610677}}, "EndTime": 1608155989.400474, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.400456}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.143603006998698, "sum": 1.143603006998698, "min": 1.143603006998698}}, "EndTime": 1608155989.400538, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.40052}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2671586608886718, "sum": 1.2671586608886718, "min": 1.2671586608886718}}, "EndTime": 1608155989.400602, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.400584}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1955855051676432, "sum": 1.1955855051676432, "min": 1.1955855051676432}}, "EndTime": 1608155989.400667, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.400649}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8978090159098308, "sum": 0.8978090159098308, "min": 0.8978090159098308}}, "EndTime": 1608155989.400732, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.400714}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.36077023824056, "sum": 1.36077023824056, "min": 1.36077023824056}}, "EndTime": 1608155989.400802, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.400784}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8303630193074544, "sum": 0.8303630193074544, "min": 0.8303630193074544}}, "EndTime": 1608155989.400867, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.400849}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0781466674804687, "sum": 1.0781466674804687, "min": 1.0781466674804687}}, "EndTime": 1608155989.400929, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.400913}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1538420867919923, "sum": 1.1538420867919923, "min": 1.1538420867919923}}, "EndTime": 1608155989.400995, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.400976}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.222900670369466, "sum": 1.222900670369466, "min": 1.222900670369466}}, "EndTime": 1608155989.40106, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.401042}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.102478370666504, "sum": 1.102478370666504, "min": 1.102478370666504}}, "EndTime": 1608155989.401121, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.401104}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1229730478922526, "sum": 1.1229730478922526, "min": 1.1229730478922526}}, "EndTime": 1608155989.401184, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.401167}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0047223917643229, "sum": 1.0047223917643229, "min": 1.0047223917643229}}, "EndTime": 1608155989.401249, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.40123}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8317714182535807, "sum": 0.8317714182535807, "min": 0.8317714182535807}}, "EndTime": 1608155989.401314, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.401295}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1840608469645182, "sum": 1.1840608469645182, "min": 1.1840608469645182}}, "EndTime": 1608155989.401374, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.401357}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.003740997314453, "sum": 1.003740997314453, "min": 1.003740997314453}}, "EndTime": 1608155989.40147, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.401451}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0580668004353841, "sum": 1.0580668004353841, "min": 1.0580668004353841}}, "EndTime": 1608155989.401535, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.401517}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.218548838297526, "sum": 1.218548838297526, "min": 1.218548838297526}}, "EndTime": 1608155989.401601, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.401583}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9647941080729167, "sum": 0.9647941080729167, "min": 0.9647941080729167}}, "EndTime": 1608155989.401674, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.401654}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0078194046020508, "sum": 1.0078194046020508, "min": 1.0078194046020508}}, "EndTime": 1608155989.401742, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.401724}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9682864379882813, "sum": 0.9682864379882813, "min": 0.9682864379882813}}, "EndTime": 1608155989.401887, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.401863}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9566773478190104, "sum": 0.9566773478190104, "min": 0.9566773478190104}}, "EndTime": 1608155989.401953, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.401935}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1932872263590495, "sum": 1.1932872263590495, "min": 1.1932872263590495}}, "EndTime": 1608155989.40202, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.402001}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.119784164428711, "sum": 1.119784164428711, "min": 1.119784164428711}}, "EndTime": 1608155989.402093, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.402075}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.326574223836263, "sum": 1.326574223836263, "min": 1.326574223836263}}, "EndTime": 1608155989.402159, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.402141}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.4062881724039713, "sum": 1.4062881724039713, "min": 1.4062881724039713}}, "EndTime": 1608155989.402229, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.40221}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2846173350016277, "sum": 1.2846173350016277, "min": 1.2846173350016277}}, "EndTime": 1608155989.402304, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.402285}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2594181823730468, "sum": 1.2594181823730468, "min": 1.2594181823730468}}, "EndTime": 1608155989.402381, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.402361}
#
# [12/16/2020 21:59:49 INFO 140694911018816] #quality_metric: host=algo-1, epoch=0, train mse_objective <loss>=0.915729268392
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 56.667736856063996, "sum": 56.667736856063996, "min": 56.667736856063996}}, "EndTime": 1608155989.462228, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.462168}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 50.331393855633124, "sum": 50.331393855633124, "min": 50.331393855633124}}, "EndTime": 1608155989.462307, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.462284}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 75.70261160217889, "sum": 75.70261160217889, "min": 75.70261160217889}}, "EndTime": 1608155989.462379, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.462359}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 50.944248803771366, "sum": 50.944248803771366, "min": 50.944248803771366}}, "EndTime": 1608155989.462458, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.462438}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 52.967098727084625, "sum": 52.967098727084625, "min": 52.967098727084625}}, "EndTime": 1608155989.462519, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.462506}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 66.48221984712204, "sum": 66.48221984712204, "min": 66.48221984712204}}, "EndTime": 1608155989.462554, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.462545}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 59.16386498555099, "sum": 59.16386498555099, "min": 59.16386498555099}}, "EndTime": 1608155989.462615, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.462597}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 66.57159015919902, "sum": 66.57159015919902, "min": 66.57159015919902}}, "EndTime": 1608155989.462692, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.462672}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 53.14417546338374, "sum": 53.14417546338374, "min": 53.14417546338374}}, "EndTime": 1608155989.46276, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.462742}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 83.20279519864829, "sum": 83.20279519864829, "min": 83.20279519864829}}, "EndTime": 1608155989.462835, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.462816}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 49.40072750809169, "sum": 49.40072750809169, "min": 49.40072750809169}}, "EndTime": 1608155989.462913, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.462893}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.58967356162496, "sum": 63.58967356162496, "min": 63.58967356162496}}, "EndTime": 1608155989.462983, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.462963}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 60.066277834448485, "sum": 60.066277834448485, "min": 60.066277834448485}}, "EndTime": 1608155989.463056, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.463037}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 53.26896304895382, "sum": 53.26896304895382, "min": 53.26896304895382}}, "EndTime": 1608155989.463123, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.463104}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 44.1913273122051, "sum": 44.1913273122051, "min": 44.1913273122051}}, "EndTime": 1608155989.463179, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.463161}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 68.59176575311339, "sum": 68.59176575311339, "min": 68.59176575311339}}, "EndTime": 1608155989.463245, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.463227}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.4912062541093, "sum": 63.4912062541093, "min": 63.4912062541093}}, "EndTime": 1608155989.463308, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.46329}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 47.93224353601437, "sum": 47.93224353601437, "min": 47.93224353601437}}, "EndTime": 1608155989.463373, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.463355}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 76.44460798962281, "sum": 76.44460798962281, "min": 76.44460798962281}}, "EndTime": 1608155989.463436, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.463419}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 67.08340650501817, "sum": 67.08340650501817, "min": 67.08340650501817}}, "EndTime": 1608155989.463503, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.463485}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 40.259172609536954, "sum": 40.259172609536954, "min": 40.259172609536954}}, "EndTime": 1608155989.463562, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.463544}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 54.276770317908564, "sum": 54.276770317908564, "min": 54.276770317908564}}, "EndTime": 1608155989.463633, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.463615}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 40.677292587733504, "sum": 40.677292587733504, "min": 40.677292587733504}}, "EndTime": 1608155989.4637, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.463681}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 43.13304855799911, "sum": 43.13304855799911, "min": 43.13304855799911}}, "EndTime": 1608155989.463763, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.463745}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 67.78685873805887, "sum": 67.78685873805887, "min": 67.78685873805887}}, "EndTime": 1608155989.463826, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.46381}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 68.55964190416996, "sum": 68.55964190416996, "min": 68.55964190416996}}, "EndTime": 1608155989.463894, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.463875}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 77.78160716519497, "sum": 77.78160716519497, "min": 77.78160716519497}}, "EndTime": 1608155989.463957, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.46394}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 74.88657917362629, "sum": 74.88657917362629, "min": 74.88657917362629}}, "EndTime": 1608155989.464018, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.464001}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 67.9911248613112, "sum": 67.9911248613112, "min": 67.9911248613112}}, "EndTime": 1608155989.46408, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.464062}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 65.54425734947297, "sum": 65.54425734947297, "min": 65.54425734947297}}, "EndTime": 1608155989.46415, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.464132}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 71.50758592858173, "sum": 71.50758592858173, "min": 71.50758592858173}}, "EndTime": 1608155989.464217, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.464199}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 72.71514026717384, "sum": 72.71514026717384, "min": 72.71514026717384}}, "EndTime": 1608155989.464287, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.464269}
#
# [12/16/2020 21:59:49 INFO 140694911018816] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=56.6677368561
# [12/16/2020 21:59:49 INFO 140694911018816] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=40.2591726095
# [12/16/2020 21:59:49 INFO 140694911018816] Epoch 0: Loss improved. Updating best model
# [12/16/2020 21:59:49 INFO 140694911018816] Saving model for epoch: 0
# [12/16/2020 21:59:49 INFO 140694911018816] Saved checkpoint to "/tmp/tmpZDj4k1/mx-mod-0000.params"
# [12/16/2020 21:59:49 INFO 140694911018816] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Records Since Last Reset": {"count": 1, "max": 354, "sum": 354.0, "min": 354}, "Total Batches Seen": {"count": 1, "max": 9, "sum": 9.0, "min": 9}, "Total Records Seen": {"count": 1, "max": 808, "sum": 808.0, "min": 808}, "Max Records Seen Between Resets": {"count": 1, "max": 354, "sum": 354.0, "min": 354}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1608155989.473968, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1608155989.307339}
#
# [12/16/2020 21:59:49 INFO 140694911018816] #throughput_metric: host=algo-1, train throughput=2122.71148504 records/second
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7749147669474283, "sum": 0.7749147669474283, "min": 0.7749147669474283}}, "EndTime": 1608155989.553378, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.553312}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7250791295369466, "sum": 0.7250791295369466, "min": 0.7250791295369466}}, "EndTime": 1608155989.553486, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.55347}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0809103393554687, "sum": 1.0809103393554687, "min": 1.0809103393554687}}, "EndTime": 1608155989.553546, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.553533}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7130471801757813, "sum": 0.7130471801757813, "min": 0.7130471801757813}}, "EndTime": 1608155989.553601, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.553585}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8171704991658528, "sum": 0.8171704991658528, "min": 0.8171704991658528}}, "EndTime": 1608155989.553641, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.553632}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8731551615397135, "sum": 0.8731551615397135, "min": 0.8731551615397135}}, "EndTime": 1608155989.553681, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.553666}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8582598876953125, "sum": 0.8582598876953125, "min": 0.8582598876953125}}, "EndTime": 1608155989.553734, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.553723}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8635450744628906, "sum": 0.8635450744628906, "min": 0.8635450744628906}}, "EndTime": 1608155989.553795, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.553778}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7794249471028646, "sum": 0.7794249471028646, "min": 0.7794249471028646}}, "EndTime": 1608155989.553861, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.553844}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1491569519042968, "sum": 1.1491569519042968, "min": 1.1491569519042968}}, "EndTime": 1608155989.553928, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.553909}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7216996129353841, "sum": 0.7216996129353841, "min": 0.7216996129353841}}, "EndTime": 1608155989.553993, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.553975}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9221294021606445, "sum": 0.9221294021606445, "min": 0.9221294021606445}}, "EndTime": 1608155989.55406, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554041}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8433832550048828, "sum": 0.8433832550048828, "min": 0.8433832550048828}}, "EndTime": 1608155989.554119, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554102}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8080343373616536, "sum": 0.8080343373616536, "min": 0.8080343373616536}}, "EndTime": 1608155989.554191, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554172}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7946417617797852, "sum": 0.7946417617797852, "min": 0.7946417617797852}}, "EndTime": 1608155989.554256, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554239}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8801151529947917, "sum": 0.8801151529947917, "min": 0.8801151529947917}}, "EndTime": 1608155989.55432, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554302}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.854274533589681, "sum": 0.854274533589681, "min": 0.854274533589681}}, "EndTime": 1608155989.554383, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554367}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7281576792399088, "sum": 0.7281576792399088, "min": 0.7281576792399088}}, "EndTime": 1608155989.554448, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.55443}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0187201690673828, "sum": 1.0187201690673828, "min": 1.0187201690673828}}, "EndTime": 1608155989.554513, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554493}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8598410034179688, "sum": 0.8598410034179688, "min": 0.8598410034179688}}, "EndTime": 1608155989.554579, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554561}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8981742223103841, "sum": 0.8981742223103841, "min": 0.8981742223103841}}, "EndTime": 1608155989.554646, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554627}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8399612935384114, "sum": 0.8399612935384114, "min": 0.8399612935384114}}, "EndTime": 1608155989.554708, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.55469}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.883816909790039, "sum": 0.883816909790039, "min": 0.883816909790039}}, "EndTime": 1608155989.554772, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554754}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8522575124104818, "sum": 0.8522575124104818, "min": 0.8522575124104818}}, "EndTime": 1608155989.554836, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554819}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9542441304524739, "sum": 0.9542441304524739, "min": 0.9542441304524739}}, "EndTime": 1608155989.5549, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554883}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9683025614420573, "sum": 0.9683025614420573, "min": 0.9683025614420573}}, "EndTime": 1608155989.554964, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.554946}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.0689102935791015, "sum": 1.0689102935791015, "min": 1.0689102935791015}}, "EndTime": 1608155989.555028, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.555011}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.068066635131836, "sum": 1.068066635131836, "min": 1.068066635131836}}, "EndTime": 1608155989.555095, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.555076}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.3212970733642577, "sum": 1.3212970733642577, "min": 1.3212970733642577}}, "EndTime": 1608155989.555155, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.555137}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2242767079671224, "sum": 1.2242767079671224, "min": 1.2242767079671224}}, "EndTime": 1608155989.555213, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.555196}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.391583709716797, "sum": 1.391583709716797, "min": 1.391583709716797}}, "EndTime": 1608155989.555281, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.555263}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.396774393717448, "sum": 1.396774393717448, "min": 1.396774393717448}}, "EndTime": 1608155989.555346, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.555328}
#
# [12/16/2020 21:59:49 INFO 140694911018816] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.774914766947
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 47.16155993584359, "sum": 47.16155993584359, "min": 47.16155993584359}}, "EndTime": 1608155989.61991, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.619847}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 42.63464848357852, "sum": 42.63464848357852, "min": 42.63464848357852}}, "EndTime": 1608155989.619994, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.619972}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 62.49322658954281, "sum": 62.49322658954281, "min": 62.49322658954281}}, "EndTime": 1608155989.620069, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620049}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 43.22598624465489, "sum": 43.22598624465489, "min": 43.22598624465489}}, "EndTime": 1608155989.62013, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620113}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 48.66570093136023, "sum": 48.66570093136023, "min": 48.66570093136023}}, "EndTime": 1608155989.620196, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620178}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 43.34670401091623, "sum": 43.34670401091623, "min": 43.34670401091623}}, "EndTime": 1608155989.620264, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620245}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 46.079252186388075, "sum": 46.079252186388075, "min": 46.079252186388075}}, "EndTime": 1608155989.620332, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620312}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 47.27045176288869, "sum": 47.27045176288869, "min": 47.27045176288869}}, "EndTime": 1608155989.620399, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620381}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 45.79308701505755, "sum": 45.79308701505755, "min": 45.79308701505755}}, "EndTime": 1608155989.620464, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620447}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 69.13525167786248, "sum": 69.13525167786248, "min": 69.13525167786248}}, "EndTime": 1608155989.620531, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620512}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 42.42006269775995, "sum": 42.42006269775995, "min": 42.42006269775995}}, "EndTime": 1608155989.620599, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.62058}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 53.13558801329962, "sum": 53.13558801329962, "min": 53.13558801329962}}, "EndTime": 1608155989.620666, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620648}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 46.22308319393951, "sum": 46.22308319393951, "min": 46.22308319393951}}, "EndTime": 1608155989.620732, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620715}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 47.93401072284963, "sum": 47.93401072284963, "min": 47.93401072284963}}, "EndTime": 1608155989.620799, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.62078}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 51.66705624419864, "sum": 51.66705624419864, "min": 51.66705624419864}}, "EndTime": 1608155989.620863, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620845}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 45.164851575794785, "sum": 45.164851575794785, "min": 45.164851575794785}}, "EndTime": 1608155989.62093, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620912}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 53.515167538482366, "sum": 53.515167538482366, "min": 53.515167538482366}}, "EndTime": 1608155989.620996, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.620978}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 41.37326004481552, "sum": 41.37326004481552, "min": 41.37326004481552}}, "EndTime": 1608155989.621062, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621045}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 65.16580018902769, "sum": 65.16580018902769, "min": 65.16580018902769}}, "EndTime": 1608155989.621127, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621108}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 56.86548444540194, "sum": 56.86548444540194, "min": 56.86548444540194}}, "EndTime": 1608155989.621192, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621173}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 42.666972396397355, "sum": 42.666972396397355, "min": 42.666972396397355}}, "EndTime": 1608155989.621258, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.62124}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 47.36157075485381, "sum": 47.36157075485381, "min": 47.36157075485381}}, "EndTime": 1608155989.621323, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621305}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 41.167657040133335, "sum": 41.167657040133335, "min": 41.167657040133335}}, "EndTime": 1608155989.62139, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621373}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 43.415369770314435, "sum": 43.415369770314435, "min": 43.415369770314435}}, "EndTime": 1608155989.621483, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621464}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 65.77415488970162, "sum": 65.77415488970162, "min": 65.77415488970162}}, "EndTime": 1608155989.621549, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621531}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 67.0133295909013, "sum": 67.0133295909013, "min": 67.0133295909013}}, "EndTime": 1608155989.621615, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621597}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 69.14013755911648, "sum": 69.14013755911648, "min": 69.14013755911648}}, "EndTime": 1608155989.621704, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621683}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 69.57388335879486, "sum": 69.57388335879486, "min": 69.57388335879486}}, "EndTime": 1608155989.621772, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621755}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 69.90838309443824, "sum": 69.90838309443824, "min": 69.90838309443824}}, "EndTime": 1608155989.621837, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621819}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 72.09555215204117, "sum": 72.09555215204117, "min": 72.09555215204117}}, "EndTime": 1608155989.621901, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621882}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 78.36238279466582, "sum": 78.36238279466582, "min": 78.36238279466582}}, "EndTime": 1608155989.621964, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1608155989.621947}
#
# ...
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.006108627319336, "sum": 1.006108627319336, "min": 1.006108627319336}}, "EndTime": 1608155991.259752, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.259734}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9514550654093424, "sum": 0.9514550654093424, "min": 0.9514550654093424}}, "EndTime": 1608155991.259811, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.259794}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9825564320882162, "sum": 0.9825564320882162, "min": 0.9825564320882162}}, "EndTime": 1608155991.259875, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.259856}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9648653920491537, "sum": 0.9648653920491537, "min": 0.9648653920491537}}, "EndTime": 1608155991.259934, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.259917}
#
# [12/16/2020 21:59:51 INFO 140694911018816] #quality_metric: host=algo-1, epoch=11, train mse_objective <loss>=0.410455786387
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 25.676831311518605, "sum": 25.676831311518605, "min": 25.676831311518605}}, "EndTime": 1608155991.321535, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.321445}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 24.311180001438252, "sum": 24.311180001438252, "min": 24.311180001438252}}, "EndTime": 1608155991.321696, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.32167}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 28.167066361496943, "sum": 28.167066361496943, "min": 28.167066361496943}}, "EndTime": 1608155991.32177, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.321751}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 25.270145699529365, "sum": 25.270145699529365, "min": 25.270145699529365}}, "EndTime": 1608155991.321841, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.321822}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.110360891512126, "sum": 19.110360891512126, "min": 19.110360891512126}}, "EndTime": 1608155991.321907, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.32189}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.735678153462928, "sum": 19.735678153462928, "min": 19.735678153462928}}, "EndTime": 1608155991.321974, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.321955}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.70796800367903, "sum": 19.70796800367903, "min": 19.70796800367903}}, "EndTime": 1608155991.322041, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322022}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.563761154023727, "sum": 19.563761154023727, "min": 19.563761154023727}}, "EndTime": 1608155991.322124, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322087}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 26.60930901234693, "sum": 26.60930901234693, "min": 26.60930901234693}}, "EndTime": 1608155991.322217, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322196}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 29.575294082080667, "sum": 29.575294082080667, "min": 29.575294082080667}}, "EndTime": 1608155991.322287, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322267}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 25.385996459734322, "sum": 25.385996459734322, "min": 25.385996459734322}}, "EndTime": 1608155991.322355, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322335}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 25.903975942126007, "sum": 25.903975942126007, "min": 25.903975942126007}}, "EndTime": 1608155991.322441, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322402}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 18.771128021844543, "sum": 18.771128021844543, "min": 18.771128021844543}}, "EndTime": 1608155991.322515, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322494}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.354804048443786, "sum": 19.354804048443786, "min": 19.354804048443786}}, "EndTime": 1608155991.322587, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322566}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 18.966983870704574, "sum": 18.966983870704574, "min": 18.966983870704574}}, "EndTime": 1608155991.322652, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322635}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 19.715664627528426, "sum": 19.715664627528426, "min": 19.715664627528426}}, "EndTime": 1608155991.322715, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322698}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 28.35181224346161, "sum": 28.35181224346161, "min": 28.35181224346161}}, "EndTime": 1608155991.322777, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.32276}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 26.02939249029254, "sum": 26.02939249029254, "min": 26.02939249029254}}, "EndTime": 1608155991.322837, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322821}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 32.35178449720439, "sum": 32.35178449720439, "min": 32.35178449720439}}, "EndTime": 1608155991.322899, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322881}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 28.71986611512038, "sum": 28.71986611512038, "min": 28.71986611512038}}, "EndTime": 1608155991.322962, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.322946}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 24.34440029729711, "sum": 24.34440029729711, "min": 24.34440029729711}}, "EndTime": 1608155991.323026, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.32301}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 22.630673332969742, "sum": 22.630673332969742, "min": 22.630673332969742}}, "EndTime": 1608155991.323086, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.32307}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 23.53844383211419, "sum": 23.53844383211419, "min": 23.53844383211419}}, "EndTime": 1608155991.323149, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.323131}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 23.87586528003806, "sum": 23.87586528003806, "min": 23.87586528003806}}, "EndTime": 1608155991.32321, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.323194}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 64.08933363810624, "sum": 64.08933363810624, "min": 64.08933363810624}}, "EndTime": 1608155991.323269, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.323253}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 64.12237890640108, "sum": 64.12237890640108, "min": 64.12237890640108}}, "EndTime": 1608155991.323334, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.323316}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 64.60378575088954, "sum": 64.60378575088954, "min": 64.60378575088954}}, "EndTime": 1608155991.323395, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.323379}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.874805393785536, "sum": 63.874805393785536, "min": 63.874805393785536}}, "EndTime": 1608155991.323454, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.323438}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 65.9284841518591, "sum": 65.9284841518591, "min": 65.9284841518591}}, "EndTime": 1608155991.323514, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.323498}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 67.92900013687587, "sum": 67.92900013687587, "min": 67.92900013687587}}, "EndTime": 1608155991.323574, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.323558}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 64.35275631139774, "sum": 64.35275631139774, "min": 64.35275631139774}}, "EndTime": 1608155991.323637, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.32362}
#
# #metrics {"Metrics": {"validation_mse_objective": {"count": 1, "max": 63.90203273886501, "sum": 63.90203273886501, "min": 63.90203273886501}}, "EndTime": 1608155991.323698, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.32368}
#
# [12/16/2020 21:59:51 INFO 140694911018816] #quality_metric: host=algo-1, epoch=11, validation mse_objective <loss>=25.6768313115
# [12/16/2020 21:59:51 INFO 140694911018816] #early_stopping_criteria_metric: host=algo-1, epoch=11, criteria=mse_objective, value=18.7711280218
# [12/16/2020 21:59:51 INFO 140694911018816] Saving model for epoch: 11
# [12/16/2020 21:59:51 INFO 140694911018816] Saved checkpoint to "/tmp/tmpZaKllA/mx-mod-0000.params"
# [12/16/2020 21:59:51 INFO 140694911018816] Early stop condition met. Stopping training.
# [12/16/2020 21:59:51 INFO 140694911018816] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Batches Since Last Reset": {"count": 1, "max": 4, "sum": 4.0, "min": 4}, "Number of Records Since Last Reset": {"count": 1, "max": 354, "sum": 354.0, "min": 354}, "Total Batches Seen": {"count": 1, "max": 53, "sum": 53.0, "min": 53}, "Total Records Seen": {"count": 1, "max": 4702, "sum": 4702.0, "min": 4702}, "Max Records Seen Between Resets": {"count": 1, "max": 354, "sum": 354.0, "min": 354}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1608155991.330082, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 11}, "StartTime": 1608155991.173589}
#
# [12/16/2020 21:59:51 INFO 140694911018816] #throughput_metric: host=algo-1, train throughput=2260.00309901 records/second
# [12/16/2020 21:59:51 WARNING 140694911018816] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/16/2020 21:59:51 WARNING 140694911018816] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/16/2020 21:59:51 INFO 140694911018816] #early_stopping_criteria_metric: host=algo-1, epoch=11, criteria=mse_objective, value=18.7711280218
# [12/16/2020 21:59:51 INFO 140694911018816] #validation_score (algo-1) : ('mse_objective', 18.77065371522809)
# [12/16/2020 21:59:51 INFO 140694911018816] #validation_score (algo-1) : ('mse', 18.77065371522809)
# [12/16/2020 21:59:51 INFO 140694911018816] #validation_score (algo-1) : ('absolute_loss', 2.929951318419806)
# [12/16/2020 21:59:51 INFO 140694911018816] #quality_metric: host=algo-1, validation mse_objective <loss>=18.7706537152
# [12/16/2020 21:59:51 INFO 140694911018816] #quality_metric: host=algo-1, validation mse <loss>=18.7706537152
# [12/16/2020 21:59:51 INFO 140694911018816] #quality_metric: host=algo-1, validation absolute_loss <loss>=2.92995131842
# [12/16/2020 21:59:51 INFO 140694911018816] Best model found for hyperparameters: {"lr_scheduler_step": 100, "wd": 0.01, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.1, "lr_scheduler_minimum_lr": 1e-05}
# [12/16/2020 21:59:51 INFO 140694911018816] Saved checkpoint to "/tmp/tmpMlxDka/mx-mod-0000.params"
# [12/16/2020 21:59:51 INFO 140694911018816] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2634.1941356658936, "sum": 2634.1941356658936, "min": 2634.1941356658936}, "finalize.time": {"count": 1, "max": 68.76206398010254, "sum": 68.76206398010254, "min": 68.76206398010254}, "initialize.time": {"count": 1, "max": 208.67300033569336, "sum": 208.67300033569336, "min": 208.67300033569336}, "check_early_stopping.time": {"count": 13, "max": 1.374959945678711, "sum": 8.58163833618164, "min": 0.1518726348876953}, "setuptime": {"count": 1, "max": 32.43112564086914, "sum": 32.43112564086914, "min": 32.43112564086914}, "update.time": {"count": 12, "max": 193.12715530395508, "sum": 1972.4433422088623, "min": 151.05199813842773}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1608155991.406314, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1608155989.098061}
#
#
# 2020-12-16 22:00:28 Completed - Training job completed
# Training seconds: 78
# Billable seconds: 78

# %% [markdown]
# ## Hosting
# Now that we've trained the `Linear Learner` algorithm on our data, let's deploy a model that's hosted behind a real-time endpoint.

# %%
ll_predictor = ll.deploy(initial_instance_count=1,instance_type='ml.m4.xlarge')
# Out:
# ------

# %% [markdown]
# ### (Optional) Delete the Endpoint
#
# If you're ready to be done with this notebook, please run the delete_endpoint line in the cell below.  This will remove the hosted endpoint you created and avoid any charges from a stray instance being left on.

# %%
sagemaker.Session().delete_endpoint(ll_predictor.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
